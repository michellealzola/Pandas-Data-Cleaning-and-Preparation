# %% [markdown]
# ### **Problem 1: Shift-Based Operator Performance and Anomaly Flagging**
#
# The QA department wants to evaluate operator consistency across shifts and detect any red flags.
#
# **Your tasks:**
#
# 1. Normalize operator names (e.g., title case, strip whitespace).
# 2. Extract and validate phone numbers (must be 10-digit only).
# 3. Ensure email addresses are valid (basic regex rule).
# 4. Count total batches handled by each operator, grouped by shift.
# 5. Identify operators whose scrap rate averaged > 10% across the month.
# 6. Flag any batch that failed QA **and** had scrap rate > 15%.
# 7. Summarize: Which shift had the highest failure rate?
#
# *Hint: You may need `.groupby()` and aggregation, and build a `Flag` column conditionally.*

# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv('Spool_Manufacturing_Batch_Log.csv')

# %%
df = pd.DataFrame(data)

# %%
df.head(3)
# Out:
#                                Batch ID Date Produced Material Type  Color  \
# 0  eb6221c8-f45a-49f6-8c0c-ee28f5a29fc0    2025-05-01           PLA  Black
# 1  9748d109-45e1-4bb0-98af-53396946b791    2025-05-01           PLA    Red
# 2  35de154c-67d6-4144-a9e2-8afe65353fb2    2025-05-01           ABS   Blue
#
#   Production Line  Weight (g)  Scrap Rate (%) Pass/Fail         Operator  \
# 0          Line 2     1024.84            1.79      Pass  Jacqueline Bass
# 1          Line 1     1032.38            4.28      Pass     Kristen Cole
# 2          Line 4      988.29            1.65      Pass    Sherry Bryant
#
#                    Phone                  Email    Shift Machine Barcode  \
# 0  001-988-061-3911x7775  haynesdavid@yahoo.com  Shift C         MCH-001
# 1      300-905-2906x4997   theodore63@yahoo.com  Shift A         MCH-001
# 2   001-741-699-1830x254     timothy04@knox.net  Shift C         MCH-001
#
#   Lot Number
# 0      L9935
# 1      L4257
# 2      L3615

# %%
# 1. Normalize operator names (e.g., title case, strip whitespace).
df['Operator'] = df['Operator'].str.title().str.strip()

# %%
df['Operator'].head(3)
# Out:
# 0    Jacqueline Bass
# 1       Kristen Cole
# 2      Sherry Bryant
# Name: Operator, dtype: object

# %%
# 2. Extract and validate phone numbers (must be 10-digit only).
df['Phone'] = df['Phone'].astype(str)

# %%
df['Phone Digits'] = df['Phone'].str.extract(r'(\d{10})')

# %%
df['Valid Phone'] = df['Phone Digits'].apply(lambda x: 'VALID' if pd.notnull(x) else 'INVALID')

# %%
df[['Phone', 'Phone Digits','Valid Phone']].head()
# Out:
#                    Phone Phone Digits Valid Phone
# 0  001-988-061-3911x7775          NaN     INVALID
# 1      300-905-2906x4997          NaN     INVALID
# 2   001-741-699-1830x254          NaN     INVALID
# 3      300-905-2906x4997          NaN     INVALID
# 4      300-905-2906x4997          NaN     INVALID

# %%
# Format Phone Numbers
# Convert to string
df['Phone'] = df['Phone'].astype(str)

# %%
# Split extension if exists
df[['Phone Base', 'Extension']] = df['Phone'].str.split('x', n=1, expand=True)

# %%
df[['Phone Base', 'Extension']].head(3)
# Out:
#          Phone Base Extension
# 0  001-988-061-3911      7775
# 1      300-905-2906      4997
# 2  001-741-699-1830       254

# %%
# Remove non-digits from Phone Base
df['Digits Only'] = df['Phone Base'].str.replace(r'\D', '', regex=True)

# %%
df[['Phone', 'Phone Base', 'Digits Only', 'Extension']].head(3)
# Out:
#                    Phone        Phone Base    Digits Only Extension
# 0  001-988-061-3911x7775  001-988-061-3911  0019880613911      7775
# 1      300-905-2906x4997      300-905-2906     3009052906      4997
# 2   001-741-699-1830x254  001-741-699-1830  0017416991830       254

# %%
# Determine if it has Country Code
df['Country Code'] = df['Digits Only'].apply(lambda x: x[:3] if len(x) > 10 else '')

# %%
# Get phone digits
df['Phone Digits'] = df['Digits Only'].apply(lambda x: x[-10:] if len(x) >= 10 else '')

# %%
df[['Phone', 'Phone Base', 'Country Code', 'Phone Digits', 'Extension']].head(3)
# Out:
#                    Phone        Phone Base Country Code Phone Digits Extension
# 0  001-988-061-3911x7775  001-988-061-3911          001   9880613911      7775
# 1      300-905-2906x4997      300-905-2906                3009052906      4997
# 2   001-741-699-1830x254  001-741-699-1830          001   7416991830       254

# %%
# Format Phone digits
df['Formatted Phone'] = df['Phone Digits'].apply(
    lambda x: f'{x[:3]}-{x[3:6]}-{x[6:]}' if len(x) == 10 else ''
)

# %%
df[['Phone', 'Country Code', 'Formatted Phone', 'Extension']].head(3)
# Out:
#                    Phone Country Code Formatted Phone Extension
# 0  001-988-061-3911x7775          001    988-061-3911      7775
# 1      300-905-2906x4997                 300-905-2906      4997
# 2   001-741-699-1830x254          001    741-699-1830       254

# %%
# add full constructed version
df['Final Phone'] = df.apply(
    lambda row: f"+{row['Country Code']} {row['Formatted Phone']} ext. {row['Extension']}" if row['Extension'] else f"+{row['Country Code']} {row['Formatted Phone']}", axis=1
)

# %%
df[['Phone', 'Country Code', 'Formatted Phone', 'Extension', 'Final Phone']].head(3)
# Out:
#                    Phone Country Code Formatted Phone Extension  \
# 0  001-988-061-3911x7775          001    988-061-3911      7775
# 1      300-905-2906x4997                 300-905-2906      4997
# 2   001-741-699-1830x254          001    741-699-1830       254
#
#                    Final Phone
# 0  +001 988-061-3911 ext. 7775
# 1     + 300-905-2906 ext. 4997
# 2   +001 741-699-1830 ext. 254

# %%
# 3. Ensure email addresses are valid (basic regex rule).
# email_pattern = r'^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$'
email_pattern = (
    r'^(?!.*\.\.)'                     # no double dots
    r'(?!\.)(?!.*\.$)'                 # cannot start or end with dot
    r'[A-Za-z0-9._%+-]+'
    r'@'
    r'(?!-)[A-Za-z0-9.-]+(?<!-)'       # domain cannot start or end with hyphen
    r'\.[A-Za-z]{2,}$'
)

# %%
df['Email'] = df['Email'].str.strip().str.lower()

# %%
df['Valid Email'] = df['Email'].str.match(email_pattern)

# %%
df[['Email', 'Valid Email']].head(3)
# Out:
#                    Email  Valid Email
# 0  haynesdavid@yahoo.com         True
# 1   theodore63@yahoo.com         True
# 2     timothy04@knox.net         True

# %%
# 4. Count total batches handled by each operator, grouped by shift.
df_summary = df.groupby(['Operator', 'Shift'])['Batch ID'].size().unstack().fillna(0)

# %%
df_summary.head()
# Out:
# Shift            Shift A  Shift B  Shift C
# Operator
# Amanda Anderson       11       27       18
# David Pittman         22       24       19
# Jacqueline Bass       15       23       22
# Kristen Cole          19       21       21
# Mary Anderson         22       19       17

# %%
# add total per operator (row-wise)
df_summary['Total'] = df_summary.sum(axis=1)

# %%
df_summary
# Out:
# Shift            Shift A  Shift B  Shift C  Total
# Operator
# Amanda Anderson       11       27       18     56
# David Pittman         22       24       19     65
# Jacqueline Bass       15       23       22     60
# Kristen Cole          19       21       21     61
# Mary Anderson         22       19       17     58
# Patrick Meyer         18       22       17     57
# Paul Macdonald        22       22       23     67
# Rita Graves           22       17       20     59
# Sherry Bryant         23       16       18     57

# %%
# add total per shift (column-wise)
df_summary.loc['Total'] = df_summary.sum()

# %%
df_summary
# Out:
# Shift            Shift A  Shift B  Shift C  Total
# Operator
# Amanda Anderson       11       27       18     56
# David Pittman         22       24       19     65
# Jacqueline Bass       15       23       22     60
# Kristen Cole          19       21       21     61
# Mary Anderson         22       19       17     58
# Patrick Meyer         18       22       17     57
# Paul Macdonald        22       22       23     67
# Rita Graves           22       17       20     59
# Sherry Bryant         23       16       18     57
# Total                174      191      175    540

# %%
# 5. Identify operators whose scrap rate averaged > 10% across the month.
avg_scrap_rate_per_operator = df.groupby('Operator')['Scrap Rate (%)'].mean()

# %%
avg_scrap_rate_per_operator
# Out:
# Operator
# Amanda Anderson    2.046786
# David Pittman      2.037846
# Jacqueline Bass    2.159667
# Kristen Cole       2.055902
# Mary Anderson      1.867759
# Patrick Meyer      2.291404
# Paul Macdonald     2.348358
# Rita Graves        1.992881
# Sherry Bryant      2.450877
# Name: Scrap Rate (%), dtype: float64

# %%
monthly_scrap_rate_avg_at_10_percent = df['Scrap Rate (%)'].mean() * 1.1

# %%
monthly_scrap_rate_avg_at_10_percent
# Out:
# np.float64(2.354061111111111)

# %%
df['Scrap Rate (%) per Operator'] = df['Operator'].map(avg_scrap_rate_per_operator)

# %%
df[['Operator', 'Scrap Rate (%) per Operator']].head(3)
# Out:
#           Operator  Scrap Rate (%) per Operator
# 0  Jacqueline Bass                     2.159667
# 1     Kristen Cole                     2.055902
# 2    Sherry Bryant                     2.450877

# %%
df['Scrap Alert'] = df['Scrap Rate (%) per Operator'] > monthly_scrap_rate_avg_at_10_percent

# %%
df[['Operator', 'Scrap Rate (%) per Operator','Scrap Alert']].head(3)
# Out:
#           Operator  Scrap Rate (%) per Operator  Scrap Alert
# 0  Jacqueline Bass                     2.159667        False
# 1     Kristen Cole                     2.055902        False
# 2    Sherry Bryant                     2.450877         True

# %%
# 6. Flag any batch that failed QA **and** had scrap rate > 15%.
threshold = df['Scrap Rate (%)'].mean() * 1.15
df['Failed and Scrap Rate > 15%'] = (df['Pass/Fail'] == 'Fail') & (df['Scrap Rate (%)'] > threshold)

# %%
df[['Batch ID', 'Scrap Rate (%)', 'Pass/Fail', 'Failed and Scrap Rate > 15%']].head(3)
# Out:
#                                Batch ID  Scrap Rate (%) Pass/Fail  \
# 0  eb6221c8-f45a-49f6-8c0c-ee28f5a29fc0            1.79      Pass
# 1  9748d109-45e1-4bb0-98af-53396946b791            4.28      Pass
# 2  35de154c-67d6-4144-a9e2-8afe65353fb2            1.65      Pass
#
#    Failed and Scrap Rate > 15%
# 0                        False
# 1                        False
# 2                        False

# %%
df['Batch Flag'] = df['Failed and Scrap Rate > 15%'].apply(lambda x: 'FLAGGED' if x else '')

# %%
df.groupby('Batch ID')['Failed and Scrap Rate > 15%'].sum().tail()
# Out:
# Batch ID
# fd8ae99f-34b5-4bf8-b9b9-0b8cc22e1d39    0
# fd97a12c-66fa-46d4-be36-5e6c003f797e    0
# fe3467eb-73a5-46a8-a27a-fa3eb8be30a8    0
# fe5468cf-16e5-4093-860e-dfd36c36a1a4    0
# ff3b07a7-a033-48d5-abc1-b1e2a4bf419a    0
# Name: Failed and Scrap Rate > 15%, dtype: int64

# %%
flagged_batches = df[df['Failed and Scrap Rate > 15%']]

# %%
flagged_batches
# Out:
#                                  Batch ID Date Produced Material Type  Color  \
# 29   09b1234d-7578-4bc7-ad84-d28363101b1e    2025-05-02           ABS   Blue
# 32   81d0d014-b5ae-43bf-b29f-3072c0792ca2    2025-05-02           TPU  White
# 36   d4e8db7f-8da1-4c62-b0bd-2bb048c05433    2025-05-03           PLA  White
# 37   d8531e8e-d31a-453c-9b3d-06edfdde57d2    2025-05-03           TPU  Black
# 88   3d589292-53b7-4e99-b88a-9e8c7661b2be    2025-05-05           ABS  Black
# 105  aa65b1a5-ed79-4a12-8951-d5a2b8eb0cb5    2025-05-06           PLA    Red
# 119  6e55f7e4-7186-4859-a27e-a1358bb196f0    2025-05-07           TPU  White
# 124  1d892de2-eaba-48ec-8029-c5b4499b5799    2025-05-07           PLA    Red
# 129  70a21345-d127-4bde-8bbe-84ce3fdf86bb    2025-05-08           PLA    Red
# 155  3cf4f4b8-9639-416f-9ab9-f721140d879f    2025-05-09           TPU  Black
# 163  df58c374-0692-4c94-b866-28cff7483113    2025-05-10           ABS    Red
# 180  9b774bfc-c03a-420e-96ed-fcd5fe7f477e    2025-05-11           ABS  White
# 250  a46f31c9-9985-4c83-87d4-c3de468f8839    2025-05-14           PLA   Blue
# 259  d903e3fe-d475-440b-9285-29369d6c04f9    2025-05-15           ABS  Black
# 261  70db499e-df63-4383-9bef-695c54e3ead9    2025-05-15           ABS  White
# 288  b849988c-f997-4bc0-a2dd-f7196cf20944    2025-05-17           PLA  Black
# 299  b42f4f00-c2a4-4e07-bf0e-a8ebb2ea63fc    2025-05-17           PLA    Red
# 315  37e5c270-8785-4516-bafd-5442ce761f9c    2025-05-18           ABS  Black
# 339  b05f6ce6-0f1a-4a1f-909b-d7c4e951de07    2025-05-19           TPU  White
# 341  557a8dcf-f1d0-4800-ae2e-f54c5cde93b6    2025-05-19           ABS   Blue
# 420  9f964bd8-e606-4170-866c-1daecbe76b90    2025-05-24           TPU   Blue
# 421  e82a1187-42da-45cf-ab4d-1c776a7851b3    2025-05-24           ABS  White
# 429  b51070f1-ed02-4471-8338-5fdd8cc9474e    2025-05-24           PLA  Black
# 441  d098872d-7775-4024-8cea-92628c0f4bcc    2025-05-25           PLA  Black
# 481  3f71ddce-663f-499d-b6ad-b5aa3aef9a7b    2025-05-27           PLA   Blue
# 502  a7e5ab98-097f-44c8-9c49-83816696f054    2025-05-28           ABS  Black
# 522  2824a566-adf8-4c92-b879-a68766d084e7    2025-05-30           TPU  White
#
#     Production Line  Weight (g)  Scrap Rate (%) Pass/Fail         Operator  \
# 29           Line 4     1016.56            3.46      Fail   Paul Macdonald
# 32           Line 5     1040.63            4.03      Fail  Amanda Anderson
# 36           Line 5      998.21            4.35      Fail  Jacqueline Bass
# 37           Line 2      869.01            3.23      Fail      Rita Graves
# 88           Line 4     1000.65            4.18      Fail    David Pittman
# 105          Line 2     1028.54            3.70      Fail    Mary Anderson
# 119          Line 4      966.91            3.28      Fail   Paul Macdonald
# 124          Line 4     1088.27            2.61      Fail    Mary Anderson
# 129          Line 4     1022.19            3.16      Fail    Sherry Bryant
# 155          Line 4      989.12            3.65      Fail    Sherry Bryant
# 163          Line 5     1057.91            3.19      Fail      Rita Graves
# 180          Line 6     1025.97            4.30      Fail   Paul Macdonald
# 250          Line 3     1046.31            4.86      Fail   Paul Macdonald
# 259          Line 2     1004.97            3.13      Fail      Rita Graves
# 261          Line 3      966.87            2.86      Fail    Sherry Bryant
# 288          Line 2     1011.78            3.16      Fail    David Pittman
# 299          Line 6      977.79            2.57      Fail      Rita Graves
# 315          Line 5      915.38            4.29      Fail   Paul Macdonald
# 339          Line 3     1046.78            3.91      Fail  Amanda Anderson
# 341          Line 3      973.77            2.73      Fail     Kristen Cole
# 420          Line 6      997.53            3.01      Fail      Rita Graves
# 421          Line 3      943.86            2.57      Fail    David Pittman
# 429          Line 6      972.39            2.95      Fail    David Pittman
# 441          Line 2      975.53            3.57      Fail  Amanda Anderson
# 481          Line 2     1009.83            3.06      Fail     Kristen Cole
# 502          Line 4     1034.91            2.59      Fail    Patrick Meyer
# 522          Line 4      991.37            3.33      Fail    David Pittman
#
#                      Phone  ... Extension    Digits Only Country Code  \
# 29      493-813-3210x19538  ...     19538     4938133210
# 32        406-315-7403x927  ...       927     4063157403
# 36   001-988-061-3911x7775  ...      7775  0019880613911          001
# 37       538.709.6430x8749  ...      8749     5387096430
# 88       819-303-1909x4296  ...      4296     8193031909
# 105     247-382-6261x52923  ...     52923     2473826261
# 119     493-813-3210x19538  ...     19538     4938133210
# 124     247-382-6261x52923  ...     52923     2473826261
# 129   001-741-699-1830x254  ...       254  0017416991830          001
# 155   001-741-699-1830x254  ...       254  0017416991830          001
# 163      538.709.6430x8749  ...      8749     5387096430
# 180     493-813-3210x19538  ...     19538     4938133210
# 250     493-813-3210x19538  ...     19538     4938133210
# 259      538.709.6430x8749  ...      8749     5387096430
# 261   001-741-699-1830x254  ...       254  0017416991830          001
# 288      819-303-1909x4296  ...      4296     8193031909
# 299      538.709.6430x8749  ...      8749     5387096430
# 315     493-813-3210x19538  ...     19538     4938133210
# 339       406-315-7403x927  ...       927     4063157403
# 341      300-905-2906x4997  ...      4997     3009052906
# 420      538.709.6430x8749  ...      8749     5387096430
# 421      819-303-1909x4296  ...      4296     8193031909
# 429      819-303-1909x4296  ...      4296     8193031909
# 441       406-315-7403x927  ...       927     4063157403
# 481      300-905-2906x4997  ...      4997     3009052906
# 502      (945)759-0061x325  ...       325     9457590061
# 522      819-303-1909x4296  ...      4296     8193031909
#
#     Formatted Phone                  Final Phone Valid Email  \
# 29     493-813-3210    + 493-813-3210 ext. 19538        True
# 32     406-315-7403      + 406-315-7403 ext. 927        True
# 36     988-061-3911  +001 988-061-3911 ext. 7775        True
# 37     538-709-6430     + 538-709-6430 ext. 8749        True
# 88     819-303-1909     + 819-303-1909 ext. 4296        True
# 105    247-382-6261    + 247-382-6261 ext. 52923        True
# 119    493-813-3210    + 493-813-3210 ext. 19538        True
# 124    247-382-6261    + 247-382-6261 ext. 52923        True
# 129    741-699-1830   +001 741-699-1830 ext. 254        True
# 155    741-699-1830   +001 741-699-1830 ext. 254        True
# 163    538-709-6430     + 538-709-6430 ext. 8749        True
# 180    493-813-3210    + 493-813-3210 ext. 19538        True
# 250    493-813-3210    + 493-813-3210 ext. 19538        True
# 259    538-709-6430     + 538-709-6430 ext. 8749        True
# 261    741-699-1830   +001 741-699-1830 ext. 254        True
# 288    819-303-1909     + 819-303-1909 ext. 4296        True
# 299    538-709-6430     + 538-709-6430 ext. 8749        True
# 315    493-813-3210    + 493-813-3210 ext. 19538        True
# 339    406-315-7403      + 406-315-7403 ext. 927        True
# 341    300-905-2906     + 300-905-2906 ext. 4997        True
# 420    538-709-6430     + 538-709-6430 ext. 8749        True
# 421    819-303-1909     + 819-303-1909 ext. 4296        True
# 429    819-303-1909     + 819-303-1909 ext. 4296        True
# 441    406-315-7403      + 406-315-7403 ext. 927        True
# 481    300-905-2906     + 300-905-2906 ext. 4997        True
# 502    945-759-0061      + 945-759-0061 ext. 325        True
# 522    819-303-1909     + 819-303-1909 ext. 4296        True
#
#     Scrap Rate (%) per Operator Scrap Alert Failed and Scrap Rate > 15%  \
# 29                     2.348358       False                        True
# 32                     2.046786       False                        True
# 36                     2.159667       False                        True
# 37                     1.992881       False                        True
# 88                     2.037846       False                        True
# 105                    1.867759       False                        True
# 119                    2.348358       False                        True
# 124                    1.867759       False                        True
# 129                    2.450877        True                        True
# 155                    2.450877        True                        True
# 163                    1.992881       False                        True
# 180                    2.348358       False                        True
# 250                    2.348358       False                        True
# 259                    1.992881       False                        True
# 261                    2.450877        True                        True
# 288                    2.037846       False                        True
# 299                    1.992881       False                        True
# 315                    2.348358       False                        True
# 339                    2.046786       False                        True
# 341                    2.055902       False                        True
# 420                    1.992881       False                        True
# 421                    2.037846       False                        True
# 429                    2.037846       False                        True
# 441                    2.046786       False                        True
# 481                    2.055902       False                        True
# 502                    2.291404       False                        True
# 522                    2.037846       False                        True
#
#     Batch Flag
# 29     FLAGGED
# 32     FLAGGED
# 36     FLAGGED
# 37     FLAGGED
# 88     FLAGGED
# 105    FLAGGED
# 119    FLAGGED
# 124    FLAGGED
# 129    FLAGGED
# 155    FLAGGED
# 163    FLAGGED
# 180    FLAGGED
# 250    FLAGGED
# 259    FLAGGED
# 261    FLAGGED
# 288    FLAGGED
# 299    FLAGGED
# 315    FLAGGED
# 339    FLAGGED
# 341    FLAGGED
# 420    FLAGGED
# 421    FLAGGED
# 429    FLAGGED
# 441    FLAGGED
# 481    FLAGGED
# 502    FLAGGED
# 522    FLAGGED
#
# [27 rows x 27 columns]

# %%
# 7. Summarize: Which shift had the highest failure rate?
failure = df[df['Pass/Fail'] == 'Fail'].groupby('Shift')['Pass/Fail'].count().sort_values(ascending=False)

# %%
failure
# Out:
# Shift
# Shift C    27
# Shift B    19
# Shift A    15
# Name: Pass/Fail, dtype: int64

# %%
failure_rate = (
    df.groupby('Shift')['Pass/Fail']
    .apply(lambda s: round((s == 'Fail').sum() / s.count() * 100, 2))
    .sort_values(ascending=False)
)

# %%
failure_rate
# Out:
# Shift
# Shift C    15.43
# Shift B     9.95
# Shift A     8.62
# Name: Pass/Fail, dtype: float64
